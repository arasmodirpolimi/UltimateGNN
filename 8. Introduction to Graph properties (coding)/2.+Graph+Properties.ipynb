# %% [markdown]
# # Direction

# %%
# !pip install networkx
# !pip install matplotlib
# Out:
# Requirement already satisfied: networkx in c:\users\armod\anaconda3\lib\site-packages (2.8.4)
# Requirement already satisfied: matplotlib in c:\users\armod\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\armod\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\armod\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
G.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'D'), 
('B', 'E'), ('C', 'F'), ('C', 'G')])

# %%
G

# %%
plt.axis('off')
nx.draw_networkx(G,node_size=600,font_color='white')

# %%
# To create a directed graph

DG = nx.DiGraph()
DG.add_edges_from([('A', 'B'), ('A', 'C'), ('B', 'D'), 
('B', 'E'), ('C', 'F'), ('C', 'G')])

# %%
plt.axis('off')
nx.draw_networkx(DG,node_size=600,cmap='coolwarm',font_color='white')

# %% [markdown]
# # Weight

# %%
WG = nx.Graph()
WG.add_edges_from([('A', 'B', {"weight": 10}), ('A', 'C', 
{"weight": 20}), ('B', 'D', {"weight": 30}), ('B', 'E', 
{"weight": 40}), ('C', 'F', {"weight": 50}), ('C', 'G', 
{"weight": 60})])
labels = nx.get_edge_attributes(WG, "weight")

# %%
plt.axis('off')
nx.draw_networkx(WG,
                 pos=nx.spring_layout(G, seed=0),
                 node_size=600,
                 cmap='coolwarm',
                 font_size=14,
                 font_color='white'
                 )
nx.draw_networkx_edge_labels(WG, pos=nx.spring_layout(G, seed=0), edge_labels=labels)
# Out:
# {('A', 'B'): Text(-0.17063150397490368, -0.25785521234238246, '10'),
#  ('A', 'C'): Text(0.16908485308194388, 0.2584267536065791, '20'),
#  ('B', 'D'): Text(-0.5751319512575159, -0.5819114840781281, '30'),
#  ('B', 'E'): Text(-0.3070875406419613, -0.7577069745265291, '40'),
#  ('C', 'F'): Text(0.5743060275721562, 0.5815239318372771, '50'),
#  ('C', 'G'): Text(0.3081446719975651, 0.7583070963940803, '60')}

# %% [markdown]
# # Connection

# %%
G1 = nx.Graph()
G1.add_edges_from([(1, 2), (2, 3), (3, 1), (4, 5)])
print(f"Is graph 1 connected? {nx.is_connected(G1)}")

G2 = nx.Graph()
G2.add_edges_from([(1, 2), (2, 3), (3, 1), (1, 4)])
print(f"Is graph 2 connected? {nx.is_connected(G2)}")
# Out:
# Is graph 1 connected? False
# Is graph 2 connected? True

# %%
plt.figure(figsize=(8,8))
plt.subplot(221)
plt.axis('off')
nx.draw_networkx(G1,
                 pos=nx.spring_layout(G1, seed=0),
                 node_size=600,
                 cmap='coolwarm',
                 font_size=14,
                 font_color='white'
                 )
plt.subplot(222)
plt.axis('off')
nx.draw_networkx(G2,
                 pos=nx.spring_layout(G2, seed=0),
                 node_size=600,
                 cmap='coolwarm',
                 font_size=14,
                 font_color='white'
                 )
